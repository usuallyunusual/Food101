# %% [markdown]
# Get the dataset <a href = "https://www.kaggle.com/kmader/food41">here</a>

# %% [markdown]
# # Importing necessary libraries

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 from scipy.ndimage.interpolation import rotate, shift, zoom
 import pandas as pd
 import seaborn as sns

# %% [markdown]
# # Reading data
# * Data is stored in HDF5 format which is an efficient way to store data as matrices/arrays.

# %%
f = h5py.File("/content/drive/My Drive/Data/food_c101_n10099_r64x64x3.h5","r")
f_t = h5py.File("/content/drive/My Drive/Data/food_test_c101_n1000_r64x64x3.h5","r")

# %% [markdown]
# # Viewing sample data

# %%
imshow(f["images"][0])

# %% [markdown]
# # Checking contents of the file

# %%
list(f.keys())
# Out:
# ['category', 'category_names', 'images']

# %% [markdown]
# # Assigning variables to the train set attributes

# %%
X_train = f["images"][:]
ref = f["category_names"][:]
Y_train = f["category"][:]
Y_train_nht = np.asarray([np.where((Y_train[idx]*1)==1)[0][0] for idx in range(0,10099)])

# %% [markdown]
# # Checking the dimensions of train data
# * Y_train is a one-hot representation
# * Y_train_nht is converted back to a column vector

# %%
print(X_train.shape)
print(Y_train.shape)
print(ref.shape)
print(Y_train_nht.shape)
# Out:
# (10099, 64, 64, 3)
# (10099, 101)
# (101,)
# (10099,)

# %% [markdown]
# # Assigning variables to the test set attributes

# %%
X_test = f_t["images"][:]
Y_test = f_t["category"][:]
Y_test_nht = np.asarray([np.where((Y_test[idx]*1)==1)[0][0] for idx in range(0,1000)])

# %% [markdown]
# # Checking the dimensions of the test data
# * Similar to train data, one-hot representation is converted to column vector

# %%
print(X_test.shape)
print(Y_test.shape)
print(Y_test_nht.shape)
# Out:
# (1000, 64, 64, 3)
# (1000, 101)
# (1000,)

# %% [markdown]
# # Viewing train data along with labels

# %%
idx = 1401
imshow(X_train[idx])
print(ref[np.where((Y_train[idx]*1)==1)[0][0]].decode())
# Out:
# strawberry_shortcake

# %% [markdown]
# # Displaying a sample of 25 images with labels
# * Change idx to view other data

# %%
fig, ax = plt.subplots(5,5,figsize = (15,19))
idx = 25
for i in range(5):
    for j in range(5):
        ax[i,j].imshow(X_train[idx])
        ax[i,j].set_title(ref[np.where((Y_train[idx]*1)==1)[0][0]].decode())
        idx+=1

# %% [markdown]
# # Viewing class distribution
# * Class distribution is not uniform
# * There are 101 classes and 10099 train images which implies about 100 images per class.
# * Could be insufficient data

# %%
plt.figure(figsize = (17,10))
sns.countplot(Y_train_nht)

# %% [markdown]
# # Training ResNet50 model with ImageNet weights
# * ResNet50 is a CNN model that is 50 layers deep
# * It is short for Residual Network
# * Great for visual recognition tasks
# * It is originally trained on the ImageNet Dataset
# * ImageNet had 14 million images

# %%
resnet = tf.keras.applications.ResNet50(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(64,64,3),
    pooling = "avg"
)
flat = keras.layers.Flatten()(resnet.output)
flat = keras.layers.Dense(units = 101,activation = tf.nn.sigmoid)(flat)
model = tf.keras.models.Model(inputs = resnet.input,outputs = flat)
model.summary()
model.compile(optimizer = "adam",loss = "sparse_categorical_crossentropy",metrics = ["accuracy"])
model.fit(X_train,Y_train_nht,epochs = 30,batch_size = 512,validation_split=0.18)
# Out:
# ...
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 70, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 32, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# # Viewing Results
# * All layers of the model were re-trained using Food 101 dataset
# * The model seems to overfit the training set

# %%
print(model.evaluate(X_train,Y_train_nht)[1]*100)
print(model.evaluate(X_test,Y_test_nht)[1]*100)
# Out:
# 316/316 [==============================] - 4s 13ms/step - loss: 0.8149 - accuracy: 0.8598
# 85.97881197929382
# 32/32 [==============================] - 1s 16ms/step - loss: 4.4039 - accuracy: 0.2370
# 23.70000034570694

# %% [markdown]
# # Training ResNet50 from scratch
# * We train the ResNet50 with random initialization instead of ImageNet weights

# %%
resnet = tf.keras.applications.ResNet50(
    include_top=False,
    weights=None,
    input_tensor=None,
    input_shape=(64,64,3),
    pooling = "avg"
)
flat = keras.layers.Flatten()(resnet.output)
flat = keras.layers.Dense(units = 101,activation = tf.nn.sigmoid)(flat)
model = tf.keras.models.Model(inputs = resnet.input,outputs = flat)
model.summary()
model.compile(optimizer = "adam",loss = "sparse_categorical_crossentropy",metrics = ["accuracy"])
model.fit(X_train,Y_train_nht,epochs = 30,batch_size = 512,validation_split = 0.18)
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 70, 3)    0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 32, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 32, 32, 64)   0           conv1_bn[0][0]
# ...

# %% [markdown]
# # Viewing model results
# * The model trained from scratch also tends to overfit
# * Although the model is trained for approximately 50-60 epochs, testing accuracy does not come up
# * Could imply from the previous and this model that there is insufficient data

# %%
print(model.evaluate(X_train,Y_train_nht)[1]*100)
print(model.evaluate(X_test,Y_test_nht)[1]*100)
# Out:
# 316/316 [==============================] - 4s 13ms/step - loss: 1.5692 - accuracy: 0.7546
# 75.46291947364807
# 32/32 [==============================] - 0s 13ms/step - loss: 7.0207 - accuracy: 0.0610
# 6.1000000685453415

# %% [markdown]
# # Data Augmentation
# * Defining function ```rand_jitter( )``` to,
#   1. Black out random row or column of 1 of the 3 channels (RGB) with a probability of 70%.
#   2. Shifting an image within a range of [-20, 20] on the x and y axis of the image with a probability of 70%.
#   3. Rotating the image within a range of [-20, 20] degrees around the plain of axis 0 and 1 with a probability of 70%.

# %%
def rand_jitter(temp):
  if np.random.random() > .7:
            temp[np.random.randint(0,64,1), :,np.random.randint(0,3,1)] = 0
  if np.random.random() > .7:
            temp[:, np.random.randint(0,64,1),np.random.randint(0,3,1)] = 0
  if np.random.random() > .7:
            temp = shift(temp, shift=(np.random.randint(-20,20,1)[0],np.random.randint(-20,20,1)[0],0),mode = "nearest")
  if np.random.random() > .7:
            temp = rotate(temp, angle = np.random.randint(-20,20,1)[0], reshape=False)
  return temp

# %% [markdown]
# # Viewing the effect of ```rand_jitter( )```

# %%
idx = np.random.randint(0,10099,1)[0]
fig,ax = plt.subplots(1,2)
temp = rand_jitter(np.copy(X_train[idx]))
ax[0].imshow(temp)
ax[1].imshow(X_train[idx])

# %% [markdown]
# # View how the rotation works
# * Scipy.ndimage.interpolation.rotate uses spline interpolation
# * Mode is set to ```None``` so we have black pixels

# %%
fig,ax = plt.subplots(1,2)
temp = np.copy(X_train[idx])
temp = rotate(temp, angle = np.random.randint(-20,20,1)[0], reshape=False)
ax[0].imshow(temp)
ax[1].imshow(X_train[idx])

# %% [markdown]
# # View how the Shift works
# * Scipy.ndimage.interpolation.shift uses spline interpolation
# * The mode is set to "nearest" as it estimates new pixels value using the nearest pixels

# %%
fig,ax = plt.subplots(1,2)
temp = np.copy(X_train[idx])
temp = shift(temp, shift= (4,4,0),mode = "nearest")
ax[0].imshow(temp)
ax[1].imshow(X_train[idx])

# %% [markdown]
# # Jittering the dataset
# * We jitter the training set
# * We add it to the original dataset (Augment)
# * So totally we end up with around double the size of the original dataset

# %%
X_train_jit = np.asarray([rand_jitter(np.copy(i)) for i in X_train])

# %%
X_train_jit_fin = np.concatenate((X_train_jit,X_train),axis = 0)

# %% [markdown]
# # Checking dimension of the original dataset
# * Doubling the target labels to handle the jittered dataset

# %%
X_train_jit_fin.shape
# Out:
# (20198, 64, 64, 3)

# %%
Y_train_fin = np.concatenate((Y_train_nht,Y_train_nht),axis = 0)
Y_train_fin.shape
# Out:
# (20198,)

# %% [markdown]
# # Training ResNet50 on jittered dataset with ImageNet weights

# %%
resnet = tf.keras.applications.ResNet50(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(64,64,3),
    pooling = "avg"
)
flat = keras.layers.Flatten()(resnet.output)
flat = keras.layers.Dense(units = 101,activation = tf.nn.sigmoid)(flat)
model = tf.keras.models.Model(inputs = resnet.input,outputs = flat)
model.summary()
model.compile(optimizer = "adam",loss = "sparse_categorical_crossentropy",metrics = ["accuracy"])
model.fit(X_train_jit_fin,Y_train_fin,epochs = 30,batch_size = 512)
# Out:
# Model: "functional_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 70, 3)    0           input_3[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 32, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 32, 32, 64)   0           conv1_bn[0][0]
# ...

# %% [markdown]
# # Viewing the model results
# * We see that the results have improved by about 2%
# * This definitely proves that we do not have enough data for 101 classes
# * Hence, all the models overfit

# %%
print(model.evaluate(X_train,Y_train_nht)[1]*100)
print(model.evaluate(X_test,Y_test_nht)[1]*100)
# Out:
# 316/316 [==============================] - 4s 13ms/step - loss: 1.2869e-04 - accuracy: 1.0000
# 100.0
# 32/32 [==============================] - 0s 13ms/step - loss: 4.3092 - accuracy: 0.2670
# 26.69999897480011

# %% [markdown]
# # Training ResNet50 model (Only the last layer)
# * We freeze all the original layers of the ResNet50
# * We only train the custom output fully connected layer

# %%
resnet = tf.keras.applications.ResNet50(
    include_top=False,
    weights="imagenet",
    input_tensor=None,
    input_shape=(64,64,3),
    pooling = "avg"
)
flat = keras.layers.Flatten()(resnet.output)
flat = keras.layers.Dense(units = 101,activation = tf.nn.sigmoid)(flat)
model = tf.keras.models.Model(inputs = resnet.input,outputs = flat)
for layer in model.layers[:-2]:
  layer.trainable = False
print(len(model.layers))
model.summary()
model.compile(optimizer = "adam",loss = "sparse_categorical_crossentropy",metrics = ["accuracy"])
# Out:
# 178
# Model: "functional_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_4 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 70, 3)    0           input_4[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 32, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# ...

# %%
model.fit(X_train,Y_train_nht,epochs = 30,batch_size = 512)
# Out:
# Epoch 1/30
# 20/20 [==============================] - 2s 95ms/step - loss: 4.6598 - accuracy: 0.0155
# Epoch 2/30
# 20/20 [==============================] - 1s 73ms/step - loss: 4.2038 - accuracy: 0.0280
# Epoch 3/30
# 20/20 [==============================] - 1s 73ms/step - loss: 3.7301 - accuracy: 0.0233
# Epoch 4/30
# 20/20 [==============================] - 1s 72ms/step - loss: 3.2187 - accuracy: 0.0666
# Epoch 5/30
# 20/20 [==============================] - 1s 72ms/step - loss: 2.7028 - accuracy: 0.2527
# Epoch 6/30
# 20/20 [==============================] - 1s 72ms/step - loss: 2.2448 - accuracy: 0.3579
# Epoch 7/30
# 20/20 [==============================] - 1s 73ms/step - loss: 1.8760 - accuracy: 0.4619
# Epoch 8/30
# 20/20 [==============================] - 1s 73ms/step - loss: 1.5879 - accuracy: 0.5593
# Epoch 9/30
# 20/20 [==============================] - 1s 73ms/step - loss: 1.3532 - accuracy: 0.6460
# Epoch 10/30
# ...

# %% [markdown]
# # Viewing results
# * Training only the last layer seems to give the same results as fine tuning the entire network (both on ImageNet weights)

# %%
print(model.evaluate(X_train,Y_train_nht)[1]*100)
print(model.evaluate(X_test,Y_test_nht)[1]*100)
# Out:
# 316/316 [==============================] - 4s 13ms/step - loss: 0.2302 - accuracy: 0.9875
# 98.75234961509705
# 32/32 [==============================] - 0s 13ms/step - loss: 4.1523 - accuracy: 0.2450
# 24.500000476837158

# %% [markdown]
# # <center> ------------ End of Notebook ------------ </center>
